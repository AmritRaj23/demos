# %% [markdown]
# # **Lab 3:** Vertex AI Model Deployment
# This lab deploys our trained BQML model to Vertex AI. We will then submit our inference requests for prediction in real time!

# %%
! pip install --quiet --upgrade google-cloud-aiplatform

# %%
project_id   = ""
team_name    = "" 
location     = "us" #This is currently necessary
region       = "us-central1"

dataset_name = "datathon_ds_{}".format(team_name)
bucket_name  = "gs://{}_{}".format(project_id,dataset_name)

# %%
from typing import Dict, List, Union
from google.cloud import aiplatform
from google.protobuf import json_format
from google.protobuf.struct_pb2 import Value
from google.cloud import bigquery
from google.cloud.bigquery import Client, QueryJobConfig
import json

client = bigquery.Client(project=project_id)

# %%
! gcloud config set project $project_id
# Out:
# Updated property [core/project].

# %%
! gsutil mb -l $region $bucket_name
# Out:
# Creating gs://qwiklabs-gcp-01-723f91d866d9_datathon_ds_admin/...

# %% [markdown]
# TODO enable ml.googleapis.com API

# %% [markdown]
# ## Deploying your BQML model to Vertex

# %% [markdown]
# **Step 1**: Export BQML model to GCS bucket
#
# To export your trained BQML model to the previously created bucket by follow the steps provided [[here]](https://cloud.google.com/bigquery/docs/exporting-models#export)
#
# **Step 2** Import model to vertex model registry
#
# We will now import the model to vertex ai model registry using the steps mentioned [[here]](https://cloud.google.com/vertex-ai/docs/model-registry/import-model#import_a_model_using)
#
# Under model settings select:
# *   Model framework -> tensorflow
# *   Model framework version -> 1.15
# *   Accelerator type -> None
# *   leave all other settings as default
#
# **Step 3** Deploy model to vertex endpoint (~15 mins)
#
# We will now deploy our model to an endpoint following the steps provided [[here]](https://cloud.google.com/vertex-ai/docs/predictions/get-predictions#deploy_a_model_to_an_endpoint)
#
# Under model settings select:
# *   machine type -> n1-standard-2
# *   leave all other settings as default
# *   skip model monitoring section
#
# Note that the model deployment will take several minutes (~15 mins)

# %% [markdown]
# ## Run inference on Deployed Model in real time

# %% [markdown]
# To run your first real time prediction:
# *   Select your model endpoint under deployments.
# *   Select the ```DEPLOY & TEST``` sub-menu.
# *   Under the ```Test your model``` section paste the payload provided below
#
#
# ```
# {"instances": [{"country":"India","operating_system":"ANDROID","language":"en-us","cnt_user_engagement": 72,"cnt_level_start_quickplay": 0,"cnt_level_end_quickplay": 6,"cnt_level_complete_quickplay": 3,"cnt_level_reset_quickplay": 1,"cnt_post_score": 9,"cnt_spend_virtual_currency": 0,"cnt_ad_reward": 0,"cnt_challenge_a_friend": 0,"cnt_completed_5_levels": 1,"cnt_use_extra_steps": 0,"user_first_engagement": 1533434460293005}
# ]}
# ```
#
# Congrats!!!! You have successfully recived your first prediction

# %% [markdown]
# ## Sending larger requests to the endpoint

# %%
query = f"""SELECT * FROM `{dataset_name}.cc_eval_dataset`"""
job = client.query(query)
df = job.to_dataframe()

# %%
df = df.drop(['user_pseudo_id', 'churned'], axis=1)

# %%
df.head(2)
# Out:
#          country operating_system language  cnt_user_engagement  \
# 0        Germany              IOS    de-de                    7
# 1  United States              IOS    en-us                  120
#
#    cnt_level_start_quickplay  cnt_level_end_quickplay  \
# 0                          2                        2
# 1                         40                       38
#
#    cnt_level_complete_quickplay  cnt_level_reset_quickplay  cnt_post_score  \
# 0                             0                          0               1
# 1                            20                          0              20
#
#    cnt_spend_virtual_currency  cnt_ad_reward  cnt_challenge_a_friend  \
# 0                           0              0                       0
# 1                           0              0                       0
#
#    cnt_completed_5_levels  cnt_use_extra_steps  user_first_engagement
# 0                       0                    0       1529940146726009
# 1                       0                    0       1528868733738017

# %%
df = df.dropna()

# %%
# format the dataframe for the endpoint
payload = json.loads(df.to_json(orient="records"))

# %%
def predict_custom_trained_model_sample(
    project: str,
    endpoint_id: str,
    instances: Union[Dict, List[Dict]],
    location: str = "us-central1",
    api_endpoint: str = "us-central1-aiplatform.googleapis.com",
):
    """
    `instances` can be either single instance of type dict or a list
    of instances.
    """
    # The AI Platform services require regional API endpoints.
    client_options = {"api_endpoint": api_endpoint}
    # Initialize client that will be used to create and send requests.
    # This client only needs to be created once, and can be reused for multiple requests.
    client = aiplatform.gapic.PredictionServiceClient(client_options=client_options)
    # The format of each instance should conform to the deployed model's prediction input schema.
    instances = instances if type(instances) == list else [instances]
    instances = [
        json_format.ParseDict(instance_dict, Value()) for instance_dict in instances
    ]
    parameters_dict = {}
    parameters = json_format.ParseDict(parameters_dict, Value())
    endpoint = client.endpoint_path(
        project=project, location=location, endpoint=endpoint_id
    )
    response = client.predict(
        endpoint=endpoint, instances=instances, parameters=parameters
    )
    print("response")
    print(" deployed_model_id:", response.deployed_model_id)
    # The predictions are a google.protobuf.Value representation of the model's predictions.
    predictions = response.predictions
    for prediction in predictions:
        print(" prediction:", dict(prediction))

# %%
predict_custom_trained_model_sample(
    project="<your-project-id>",
    endpoint_id="your-vertex-endpoint-id",
    location="us-central1",
    instances=payload
)
# Out:
# response
#  deployed_model_id: 6358873766637862912
#  prediction: {'predicted_churned': ['0'], 'churned_values': ['1', '0'], 'churned_probs': [0.2500426757360779, 0.7499573242639221]}
#  prediction: {'predicted_churned': ['0'], 'churned_values': ['1', '0'], 'churned_probs': [0.2942146998622611, 0.705785300137739]}
#  prediction: {'churned_probs': [0.2673844345280815, 0.7326155654719185], 'predicted_churned': ['0'], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0.2683011743429922, 0.7316988256570078], 'predicted_churned': ['0'], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['0'], 'churned_probs': [0.3544376882237117, 0.6455623117762883]}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.3698011653546153, 0.6301988346453847], 'predicted_churned': ['0']}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['0'], 'churned_probs': [0.3134395170988281, 0.686560482901172]}
#  prediction: {'predicted_churned': ['0'], 'churned_probs': [0.3698701972899763, 0.6301298027100237], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.2596973726698972, 0.7403026273301028], 'predicted_churned': ['0']}
#  prediction: {'churned_probs': [0.3140197947356673, 0.6859802052643327], 'churned_values': ['1', '0'], 'predicted_churned': ['0']}
#  prediction: {'churned_probs': [0.3019803675914206, 0.6980196324085794], 'predicted_churned': ['0'], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0.3038131685250968, 0.6961868314749031], 'predicted_churned': ['0'], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['0'], 'churned_probs': [0.3600430136481566, 0.6399569863518434]}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.6139354881314871, 0.3860645118685129], 'predicted_churned': ['1']}
#  prediction: {'churned_probs': [0.2724351894323171, 0.7275648105676829], 'predicted_churned': ['0'], 'churned_values': ['1', '0']}
#  prediction: {'predicted_churned': ['0'], 'churned_values': ['1', '0'], 'churned_probs': [0.249365062485146, 0.750634937514854]}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.8916629604840413, 0.1083370395159587], 'predicted_churned': ['1']}
#  prediction: {'predicted_churned': ['1'], 'churned_probs': [0.6730388158534056, 0.3269611841465944], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.6988978073087653, 0.3011021926912347], 'predicted_churned': ['1']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.6927948600792535, 0.3072051399207465], 'predicted_churned': ['1']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.7760492901185708, 0.2239507098814292], 'predicted_churned': ['1']}
#  prediction: {'churned_probs': [0.3194476029006074, 0.6805523970993926], 'churned_values': ['1', '0'], 'predicted_churned': ['0']}
#  prediction: {'churned_probs': [0.382247947843137, 0.617752052156863], 'predicted_churned': ['0'], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['1'], 'churned_probs': [0.5908534720992547, 0.4091465279007453]}
#  prediction: {'predicted_churned': ['0'], 'churned_probs': [0.3571274638998613, 0.6428725361001387], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['0'], 'churned_probs': [0.3035806411320547, 0.6964193588679453]}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.2832443859045787, 0.7167556140954213], 'predicted_churned': ['0']}
#  prediction: {'churned_probs': [0.5935132325628303, 0.4064867674371697], 'churned_values': ['1', '0'], 'predicted_churned': ['1']}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['0'], 'churned_probs': [0.2757465061381464, 0.7242534938618537]}
#  prediction: {'predicted_churned': ['1'], 'churned_probs': [0.8272017695630287, 0.1727982304369713], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0.5062470780526834, 0.4937529219473166], 'predicted_churned': ['1'], 'churned_values': ['1', '0']}
#  prediction: {'predicted_churned': ['1'], 'churned_values': ['1', '0'], 'churned_probs': [0.5535253297011284, 0.4464746702988716]}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.5509594058746057, 0.4490405941253943], 'predicted_churned': ['1']}
#  prediction: {'churned_probs': [0.5909984564558921, 0.4090015435441079], 'predicted_churned': ['1'], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0
 'churned_values': ['1', '0'], 'predicted_churned': ['0']}
#  prediction: {'predicted_churned': ['0'], 'churned_probs': [0.2896305260737933, 0.7103694739262068], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0.2005777960166702, 0.7994222039833299], 'churned_values': ['1', '0'], 'predicted_churned': ['0']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.4430283969360404, 0.5569716030639595], 'predicted_churned': ['0']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.7586260951712627, 0.2413739048287373], 'predicted_churned': ['1']}
#  prediction: {'predicted_churned': ['1'], 'churned_values': ['1', '0'], 'churned_probs': [0.8022933033828001, 0.1977066966171999]}

# %% [markdown]
# ## [Optional] Deploy a second version to the same endpoint
#
# You can continue to iterate on your BQML models for improving the ROC metric. Once you are comfortable with your models, we can explore the advanced features of vertex endpoints in the below sections
#
# Lets deploy a second version of our logistic model to the same endpoint and split the traffic 50% to each model.
#
# Note that deploying a new version to the same endpoint takes lesser time (~5 min)

# %% [markdown]
# ## [Optional] Lets monitor for prediction skew for incoming requests in our endpoint

# %%
#create df for data skew
df_data_skew = df.copy(deep=True)

# %%
from random import randrange

# add skew to the integer fields of our evaluation dataset 
df_data_skew['cnt_spend_virtual_currency'] = [ randrange(10000,100000)  for k in df_data_skew.index]
df_data_skew['cnt_user_engagement'] = [ randrange(2000,5000)  for k in df_data_skew.index]
df_data_skew['cnt_challenge_a_friend'] = [ randrange(10,20)  for k in df_data_skew.index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f782092c95c4> in <cell line: 2>()
#       1 #df_data_skew.loc[:,'cnt_spend_virtual_currency'] = randrange(500, 10000) #seems to prevent SettingWithCopyWarning
# ----> 2 df_data_skew['cnt_spend_virtual_currency'] = [ randrange(10000,100000)  for k in df_data_skew.index]
#       3 df_data_skew['cnt_user_engagement'] = [ randrange(2000,5000)  for k in df_data_skew.index]
#       4 df_data_skew['cnt_challenge_a_friend'] = [ randrange(10,20)  for k in df_data_skew.index]
#       5
#
# NameError: name 'df_data_skew' is not defined

# %%
df_data_skew.describe()
# Out:
#        cnt_user_engagement  cnt_level_start_quickplay  \
# count           820.000000                      820.0
# mean           3511.506098                   9.279268
# std             858.023083                  48.309329
# min            2000.000000                        0.0
# 25%            2773.500000                        1.0
# 50%            3542.500000                        2.0
# 75%            4228.000000                        6.0
# max            4987.000000                     1255.0
#
#        cnt_level_end_quickplay  cnt_level_complete_quickplay  \
# count                    820.0                         820.0
# mean                  5.636585                      2.170732
# std                  16.776841                      8.440707
# min                        0.0                           0.0
# 25%                        0.0                           0.0
# 50%                        1.0                           0.0
# 75%                        4.0                           2.0
# max                      255.0                         176.0
#
#        cnt_level_reset_quickplay  cnt_post_score  cnt_spend_virtual_currency  \
# count                      820.0           820.0                  820.000000
# mean                    2.856098        4.947561                54794.231707
# std                    40.023604       12.271887                25956.887559
# min                          0.0             0.0                10073.000000
# 25%                          0.0             0.0                33236.250000
# 50%                          0.0             2.0                54996.000000
# 75%                          0.0             5.0                76461.000000
# max                       1122.0           200.0                99929.000000
#
#        cnt_ad_reward  cnt_challenge_a_friend  cnt_completed_5_levels  \
# count          820.0              820.000000                   820.0
# mean        0.029268               14.593902                0.131707
# std         0.375205                2.945946                0.352517
# min              0.0               10.000000                     0.0
# 25%              0.0               12.000000                     0.0
# 50%              0.0               15.000000                     0.0
# 75%              0.0               17.000000                     0.0
# max              7.0               19.000000                     2.0
#
#        cnt_use_extra_steps  user_first_engagement
# count                820.0                  820.0
# mean              0.371951     1532503222071694.0
# std               1.509253   3040558481159.401367
 'churned_values': ['1', '0']}
#  prediction: {'predicted_churned': ['1'], 'churned_values': ['1', '0'], 'churned_probs': [0.639387643985923, 0.360612356014077]}
#  prediction: {'churned_probs': [0.3112944905387121, 0.688705509461288], 'predicted_churned': ['0'], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0.7188075686600148, 0.2811924313399852], 'predicted_churned': ['1'], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0.523389899126973, 0.476610100873027], 'predicted_churned': ['1'], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0.6288203016403123, 0.3711796983596877], 'churned_values': ['1', '0'], 'predicted_churned': ['1']}
#  prediction: {'churned_probs': [0.4862462961376662, 0.5137537038623338], 'predicted_churned': ['0'], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0.5005666312592683, 0.4994333687407317], 'predicted_churned': ['1'], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['0'], 'churned_probs': [0.2860107363157845, 0.7139892636842156]}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.6473929900468137, 0.3526070099531863], 'predicted_churned': ['1']}
#  prediction: {'churned_probs': [0.2644944250834351, 0.7355055749165649], 'predicted_churned': ['0'], 'churned_values': ['1', '0']}
#  prediction: {'predicted_churned': ['1'], 'churned_values': ['1', '0'], 'churned_probs': [0.6307465113771279, 0.3692534886228721]}
#  prediction: {'churned_probs': [0.4172144200742304, 0.5827855799257696], 'churned_values': ['1', '0'], 'predicted_churned': ['0']}
#  prediction: {'churned_probs': [0.2792459431346856, 0.7207540568653144], 'churned_values': ['1', '0'], 'predicted_churned': ['0']}
#  prediction: {'predicted_churned': ['0'], 'churned_values': ['1', '0'], 'churned_probs': [0.3079148601694582, 0.6920851398305418]}
#  prediction: {'churned_probs': [0.3943531763485709, 0.6056468236514292], 'churned_values': ['1', '0'], 'predicted_churned': ['0']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.1209077414089191, 0.8790922585910809], 'predicted_churned': ['0']}
#  prediction: {'predicted_churned': ['0'], 'churned_values': ['1', '0'], 'churned_probs': [0.4160678851996228, 0.5839321148003771]}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['1'], 'churned_probs': [0.8721699428577723, 0.1278300571422277]}
#  prediction: {'churned_probs': [0.7482675010550727, 0.2517324989449273], 'churned_values': ['1', '0'], 'predicted_churned': ['1']}
#  prediction: {'predicted_churned': ['1'], 'churned_probs': [0.5929662314953724, 0.4070337685046276], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0.6568475525897209, 0.3431524474102791], 'predicted_churned': ['1'], 'churned_values': ['1', '0']}
#  prediction: {'predicted_churned': ['0'], 'churned_values': ['1', '0'], 'churned_probs': [0.2904242546820699, 0.7095757453179301]}
#  prediction: {'churned_probs': [0.3404545742889902, 0.6595454257110098], 'churned_values': ['1', '0'], 'predicted_churned': ['0']}
#  prediction: {'churned_probs': [0.3775724915556353, 0.6224275084443647], 'predicted_churned': ['0'], 'churned_values': ['1', '0']}
#  prediction: {'predicted_churned': ['0'], 'churned_values': ['1', '0'], 'churned_probs': [0.3288014674477058, 0.6711985325522942]}
#  prediction: {'predicted_churned': ['0'], 'churned_values': ['1', '0'], 'churned_probs': [0.2501176724375002, 0.7498823275624997]}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.2928884384972523, 0.7071115615027477], 'predicted_churned': ['0']}
#  prediction: {'churned_probs': [0.5448547391112557, 0.4551452608887443], 'predicted_churned': ['1'], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0.5070837075345123, 0.4929162924654877], 'predicted_churned': ['1'], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.64422610108014, 0.35577389891986], 'predicted_churned': ['1']}
#  prediction: {'churned_probs': [0.3279397445198034, 0.6720602554801967], 'churned_values': ['1', '0'], 'predicted_churned': ['0']}
#  prediction: {'predicted_churned': ['0'], 'churned_values': ['1', '0'], 'churned_probs': [0.3979162350194204, 0.6020837649805796]}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['0'], 'churned_probs': [0.299616913509866, 0.700383086490134]}
#  prediction: {'predicted_churned': ['0'], 'churned_probs': [0.40493151705531, 0.59506848294469], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.4021381752458399, 0.59786182475416], 'predicted_churned': ['0']}
#  prediction: {'predicted_churned': ['0'], 'churned_probs': [0.4339146508897369, 0.5660853491102631], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.4919208573580579, 0.5080791426419421], 'predicted_churned': ['0']}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['1'], 'churned_probs': [0.6570580187620035, 0.3429419812379965]}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['1'], 'churned_probs': [0.5756936516555305, 0.4243063483444695]}
#  prediction: {'predicted_churned': ['1'], 'churned_probs': [0.7080598429341788, 0.2919401570658212], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.2937938839511723, 0.7062061160488277], 'predicted_churned': ['0']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.3506958831107788, 0.6493041168892212], 'predicted_churned': ['0']}
#  prediction: {'predicted_churned': ['0'], 'churned_values': ['1', '0'], 'churned_probs': [0.274510795898024, 0.725489204101976]}
#  prediction: {'predicted_churned': ['1'], 'churned_values': ['1', '0'], 'churned_probs': [0.6317540433313232, 0.3682459566686768]}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.7753044359002766, 0.2246955640997234], 'predicted_churned': ['1']}
#  prediction: {'churned_probs': [0.7206575185936147, 0.2793424814063853], 'predicted_churned': ['1'], 'churned_values': ['1', '0']}
#  prediction: {'churned_probs': [0.6779480216657434, 0.3220519783342566], 'predicted_churned': ['1'], 'churned_values': ['1', '0']}
#  prediction: {'churned_values': ['1', '0'], 'churned_probs': [0.7509392310439341, 0.2490607689560659], 'predicted_churned': ['1']}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['0'], 'churned_probs': [0.3882569031836863, 0.6117430968163137]}
#  prediction: {'predicted_churned': ['1'], 'churned_values': ['1', '0'], 'churned_probs': [0.8114208098385864, 0.1885791901614136]}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['1'], 'churned_probs': [0.7251852654063285, 0.2748147345936715]}
#  prediction: {'churned_probs': [0.259412794382854, 0.7405872056171461], 'churned_values': ['1', '0'], 'predicted_churned': ['0']}
#  prediction: {'churned_values': ['1', '0'], 'predicted_churned': ['0'], 'churned_probs': [0.2924028253853973, 0.7075971746146027]}
#  prediction: {'churned_probs': [0.6559769091148421, 0.3440230908851579], 'churned_values': ['1', '0'], 'predicted_churned': ['1']}
